# %%
mylist=("12" ,"13")
print(mylist)
# Out:
# ('12', '13')

# %%
house_0_list=[115910 ,128, 4]
print(house_0_list)
# Out:
# [115910, 128, 4]

# %%
house_price_m2= house_0_list[0]/house_0_list[1]
print(house_price_m2)
# Out:
# 905.546875

# %%
house_0_list.append(house_price_m2)
print(house_0_list)
# Out:
# [115910, 128, 4, 905.546875]

# %%
house_0_list=[115910 ,128, 4]
house_price_m2= house_0_list[0]/house_0_list[1]
house_0_list.append(house_price_m2)
print(house_0_list)

# Reset for next run
house_0_list.clear()
print(house_0_list)
# Out:
# [115910, 128, 4, 905.546875]
# []

# %%
house_nested_list=[
    [115910 , 128 ,4],
    [48718 , 210 ,3],
    [28977 , 58 , 2],
    [36932 , 79 , 3],
    [83903 , 111 , 3],
]
print("house_nested_list length:",len(house_nested_list))
print("house_nested_list type:", type(house_nested_list))
print(house_nested_list)
# Out:
# house_nested_list length: 5
# house_nested_list type: <class 'list'>
# [[115910, 128, 4], [48718, 210, 3], [28977, 58, 2], [36932, 79, 3], [83903, 111, 3]]

# %%
house_0_list=[
    [115910 ,128, 4],
    [48718 , 210 ,3],
    [28977 , 58 , 2],
    [36932 , 79 , 3],
    [83903 , 111 , 3],
]
print("house_nested_list length:",len(house_nested_list))
print("house_nested_list type:", type(house_nested_list))
print(house_nested_list)
# Out:
# house_nested_list length: 5
# house_nested_list type: <class 'list'>
# [[115910, 128, 4], [48718, 210, 3], [28977, 58, 2], [36932, 79, 3], [83903, 111, 3]]

# %%
house_nested_list=[
    [115910 , 128 ,4],
    [48718 , 210 ,3],
    [28977 , 58 , 2],
    [36932 , 79 , 3],
    [83903 , 111 , 3],
]

house_price_m2_list=[]

for house in house_nested_list:
    house_price_m2= house[0]/house[1]
    house_price_m2_list.append(house_price_m2)
    print(house_price_m2)   # print one at a time
# Out:
# 905.546875
# 231.9904761904762
# 499.6034482758621
# 467.49367088607596
# 755.8828828828829

# %%
house_nested_list = [
    [115910, 128, 4],
    [48718, 210, 3],
    [28977, 58, 2],
    [36932, 79, 3],
    [83903, 111, 3],
]


for house in house_nested_list:
   house_price_m2 = house[0] / house[1]   # divide price by area
   house.append(house_price_m2)
   print(house)
# Out:
# [115910, 128, 4, 905.546875]
# [48718, 210, 3, 231.9904761904762]
# [28977, 58, 2, 499.6034482758621]
# [36932, 79, 3, 467.49367088607596]
# [83903, 111, 3, 755.8828828828829]

# %%
house_nested_list = [
    [115910, 128, 4],
    [48718, 210, 3],
    [28977, 58, 2],
    [36932, 79, 3],
    [83903, 111, 3],
]

for house in house_nested_list:
    house_price_m2 = house[0] / house[1]   # divide price by area
    house.append(house_price_m2)           # add the result to this house

# print the updated nested list
for house in house_nested_list:
    print(house)
# Out:
# [115910, 128, 4, 905.546875]
# [48718, 210, 3, 231.9904761904762]
# [28977, 58, 2, 499.6034482758621]
# [36932, 79, 3, 467.49367088607596]
# [83903, 111, 3, 755.8828828828829]

# %%
house_0_dict={
    "price_approx_usd":115910,
    "surface_covered_in_m2":128,
    "rooms":4,
}
house_0_dict
# Out:
# {'price_approx_usd': 115910, 'surface_covered_in_m2': 128, 'rooms': 4}

# %%
house_0_dict["price_approx_usd"]/house_0_dict["surface_covered_in_m2"]
house_0_dict["price_per_m2"]=house_0_dict["price_approx_usd"]/house_0_dict["surface_covered_in_m2"]
house_0_dict
# Out:
# {'price_approx_usd': 115910,
#  'surface_covered_in_m2': 128,
#  'rooms': 4,
#  'price_per_m2': 905.546875}

# %%
house_rowwise=[
    {
        "price_approx_usd":115910,
        "surface_covered_in_m2":128,
        "rooms":4,
    },
    {
        "price_approx_usd":48718,
        "surface_covered_in_m2":210,
        "rooms":3,
    },
    {
         "price_approx_usd":28977,
        "surface_covered_in_m2":58,
        "rooms":2,
    },
    {
        "price_approx_usd":36932,
        "surface_covered_in_m2":79,
        "rooms":3,
    },
    {
         "price_approx_usd":83903,
        "surface_covered_in_m2":111,
        "rooms":3,
    },
    
]
house_rowwise
# Out:
# [{'price_approx_usd': 115910, 'surface_covered_in_m2': 128, 'rooms': 4},
#  {'price_approx_usd': 48718, 'surface_covered_in_m2': 210, 'rooms': 3},
#  {'price_approx_usd': 28977, 'surface_covered_in_m2': 58, 'rooms': 2},
#  {'price_approx_usd': 36932, 'surface_covered_in_m2': 79, 'rooms': 3},
#  {'price_approx_usd': 83903, 'surface_covered_in_m2': 111, 'rooms': 3}]

# %%
for house in house_rowwise:
   house["price_per_m2"]=house["price_approx_usd"]/house["surface_covered_in_m2"]

   print(house)
# Out:
# {'price_approx_usd': 115910, 'surface_covered_in_m2': 128, 'rooms': 4, 'price_per_m2': 905.546875}
# {'price_approx_usd': 48718, 'surface_covered_in_m2': 210, 'rooms': 3, 'price_per_m2': 231.9904761904762}
# {'price_approx_usd': 28977, 'surface_covered_in_m2': 58, 'rooms': 2, 'price_per_m2': 499.6034482758621}
# {'price_approx_usd': 36932, 'surface_covered_in_m2': 79, 'rooms': 3, 'price_per_m2': 467.49367088607596}
# {'price_approx_usd': 83903, 'surface_covered_in_m2': 111, 'rooms': 3, 'price_per_m2': 755.8828828828829}

# %%
house_price=[]
for house in house_rowwise:
    house_price.append(house["price_per_m2"])
sum(house_price)
len(house_price)
mean_house_price=sum(house_price)/len(house_price)
print(mean_house_price)
# Out:
# 572.1034706470593

# %%
house_columnwise={
    "price_approx_usd": [115910,48718, 28977, 36932, 83903,], 
     "surface_covered_in_m2": [128, 210, 58, 79, 111],
      "rooms": [4, 3, 2, 3, 3]
}
house_columnwise
# Out:
# {'price_approx_usd': [115910, 48718, 28977, 36932, 83903],
#  'surface_covered_in_m2': [128, 210, 58, 79, 111],
#  'rooms': [4, 3, 2, 3, 3]}

# %%
sum(house_columnwise["price_approx_usd"])
len(house_columnwise["surface_covered_in_m2"])
mean_house_price=sum(house_columnwise["price_approx_usd"])/len(house_columnwise["surface_covered_in_m2"])
mean_house_price
# Out:
# 62888.0

# %%
price=house_columnwise["price_approx_usd"]
area=house_columnwise["surface_covered_in_m2"]
zip(price, area)

# %%
price=house_columnwise["price_approx_usd"]
area=house_columnwise["surface_covered_in_m2"]
list(zip(price, area))
# Out:
# [(115910, 128), (48718, 210), (28977, 58), (36932, 79), (83903, 111)]

# %%
price=house_columnwise["price_approx_usd"]
area=house_columnwise["surface_covered_in_m2"]
for x in zip(price, area):
    print(x)
# Out:
# (115910, 128)
# (48718, 210)
# (28977, 58)
# (36932, 79)
# (83903, 111)

# %%
price=house_columnwise["price_approx_usd"]
area=house_columnwise["surface_covered_in_m2"]
for p,a in zip(price, area):
    print(p,a)
    price_m2=p/a
    print(price_m2)
# Out:
# 115910 128
# 905.546875
# 48718 210
# 231.9904761904762
# 28977 58
# 499.6034482758621
# 36932 79
# 467.49367088607596
# 83903 111
# 755.8828828828829

# %%
price=house_columnwise["price_approx_usd"]
area=house_columnwise["surface_covered_in_m2"]

price_per_m2=[]
for p,a in zip(price, area):
    price_m2=p/a
    price_per_m2.append(price_m2)
house_columnwise["price_per_m2"]=price_per_m2
house_columnwise
# Out:
# {'price_approx_usd': [115910, 48718, 28977, 36932, 83903],
#  'surface_covered_in_m2': [128, 210, 58, 79, 111],
#  'rooms': [4, 3, 2, 3, 3],
#  'price_per_m2': [905.546875,
#   231.9904761904762,
#   499.6034482758621,
#   467.49367088607596,
#   755.8828828828829]}

# %%
import pandas as pd
data={
     "price_approx_usd": [115910,48718, 28977, 36932, 83903,], 
     "surface_covered_in_m2": [128, 210, 58, 79, 111],
      "rooms": [4, 3, 2, 3, 3]
}
df_houses=pd.DataFrame(data)
df_houses
# Out:
#    price_approx_usd  surface_covered_in_m2  rooms
# 0            115910                    128      4
# 1             48718                    210      3
# 2             28977                     58      2
# 3             36932                     79      3
# 4             83903                    111      3

# %%
df1=pd.read_csv("C:/Users/USER/Downloads/mexico-real-estate-1.csv")
df2=pd.read_csv("C:/Users/USER/Downloads/mexico-real-estate-2.csv")
df3=pd.read_csv("C:/Users/USER/Downloads/mexico-real-estate-3.csv")

# %%
df1.shape
df1.info()
df1.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        700 non-null    float64
#  5   price_usd      700 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 32.9+ KB
#   property_type                            state        lat         lon  \
# 0         house                 Estado de México  19.560181  -99.233528
# 1         house                       Nuevo León  25.688436 -100.198807
# 2     apartment                         Guerrero  16.767704  -99.764383
# 3     apartment                         Guerrero  16.829782  -99.911012
# 4         house  Veracruz de Ignacio de la Llave        NaN         NaN
# ...

# %%
#remove"NaN" values
df1.dropna(inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 583 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  583 non-null    object
#  1   state          583 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        583 non-null    float64
#  5   price_usd      583 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 31.9+ KB

# %%
#remove"NaN" values
df1.dropna(inplace=True)
# Clean and convert the price column
df1["price_usd"] = (
    df1["price_usd"]
    .astype(str)  # ensure it's string
    .str.replace("$", "", regex=False)
    .str.replace(",", "")
    .astype(float)  # finally convert to float
)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 583 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  583 non-null    object
#  1   state          583 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        583 non-null    float64
#  5   price_usd      583 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 31.9+ KB

# %%
df2.shape
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            571 non-null    float64
#  3   lon            571 non-null    float64
#  4   area_m2        700 non-null    float64
#  5   price_mxn      700 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 32.9+ KB
#   property_type       state        lat         lon  area_m2  price_mxn
# 0     apartment  Nuevo León  25.721081 -100.345581     72.0  1300000.0
# 1     apartment      Puebla        NaN         NaN    190.0  2500000.0
# 2         house     Morelos  23.634501 -102.552788    360.0  5300000.0
# 3         house     Morelos        NaN         NaN     76.0   820000.0
# 4         house      Puebla        NaN         NaN    200.0  1100000.0

# %%
#remove "NaN" values
df2.dropna(inplace=True)
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 571 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  571 non-null    object
#  1   state          571 non-null    object
#  2   lat            571 non-null    float64
#  3   lon            571 non-null    float64
#  4   area_m2        571 non-null    float64
#  5   price_mxn      571 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 31.2+ KB
#   property_type             state        lat         lon  area_m2  price_mxn
# 0     apartment        Nuevo León  25.721081 -100.345581     72.0  1300000.0
# 2         house           Morelos  23.634501 -102.552788    360.0  5300000.0
# 6     apartment  Estado de México  19.272040  -99.572013     85.0  1250000.0
# 7         house   San Luis Potosí  22.138882 -100.996510    158.0  2120000.0
# 8     apartment  Distrito Federal  19.394558  -99.129707     65.0   758190.0

# %%
#remove "NaN" values
df2.dropna(inplace=True)
#df2.info()
#create "price_usd" col
df2["price_mxn"].head()
df2["price_usd"]=(df2["price_mxn"]/19).round(2)
df2.head()
# Out:
#   property_type             state        lat         lon  area_m2  price_mxn  \
# 0     apartment        Nuevo León  25.721081 -100.345581     72.0  1300000.0
# 2         house           Morelos  23.634501 -102.552788    360.0  5300000.0
# 6     apartment  Estado de México  19.272040  -99.572013     85.0  1250000.0
# 7         house   San Luis Potosí  22.138882 -100.996510    158.0  2120000.0
# 8     apartment  Distrito Federal  19.394558  -99.129707     65.0   758190.0
#
#    price_usd
# 0   68421.05
# 2  278947.37
# 6   65789.47
# 7  111578.95
# 8   39904.74

# %%
#remove "NaN" values
df2.dropna(inplace=True)
#df2.info()
#create "price_usd" col
df2["price_mxn"].head()
df2["price_usd"]=(df2["price_mxn"]/19).round(2)
#drop "price_mxn"col
df2.drop(columns=["price_mxn"], inplace=True)
df2.head()
# Out:
#   property_type             state        lat         lon  area_m2  price_usd
# 0     apartment        Nuevo León  25.721081 -100.345581     72.0   68421.05
# 2         house           Morelos  23.634501 -102.552788    360.0  278947.37
# 6     apartment  Estado de México  19.272040  -99.572013     85.0   65789.47
# 7         house   San Luis Potosí  22.138882 -100.996510    158.0  111578.95
# 8     apartment  Distrito Federal  19.394558  -99.129707     65.0   39904.74

# %%
df3.shape
df3.info()
df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   property_type            700 non-null    object
#  1   place_with_parent_names  700 non-null    object
#  2   lat-lon                  582 non-null    object
#  3   area_m2                  700 non-null    float64
#  4   price_usd                700 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 27.5+ KB
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 3         house        |México|Morelos|Temixco|Burgos Bugambilias|
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
#
# ...

# %%
#drop 'NaN' values
df3.dropna(inplace=True)
df3.head()
#split "lat-lon" col
df3[["lat", "lon"]] = df3["lat-lon"].str.split(",", expand=True)
df3.head()
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# 5         house                       |México|Jalisco|Guadalajara|
#
#                   lat-lon  area_m2  price_usd         lat          lon
# 0     19.52589,-99.151703     71.0   48550.59    19.52589   -99.151703
# 1  19.2640539,-99.5727534    233.0  168636.73  19.2640539  -99.5727534
# 2    19.268629,-99.671722    300.0   86932.69   19.268629   -99.671722
# 4    19.511938,-96.871956     84.0   68508.67   19.511938   -96.871956
# 5   20.689157,-103.366728    175.0  102763.00   20.689157  -103.366728

# %%
df3.head()
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# 5         house                       |México|Jalisco|Guadalajara|
#
#                   lat-lon  area_m2  price_usd         lat          lon
# 0     19.52589,-99.151703     71.0   48550.59    19.52589   -99.151703
# 1  19.2640539,-99.5727534    233.0  168636.73  19.2640539  -99.5727534
# 2    19.268629,-99.671722    300.0   86932.69   19.268629   -99.671722
# 4    19.511938,-96.871956     84.0   68508.67   19.511938   -96.871956
# 5   20.689157,-103.366728    175.0  102763.00   20.689157  -103.366728

# %%
#create 'state' col from "place_with_parent_names"
df3['state']=df3["place_with_parent_names"].str.split("|", expand=True)[2]
#drop cols
df3.drop(columns=["place_with_parent_names","lat-lon"], inplace=True)
df3.head()
# Out:
#   property_type  area_m2  price_usd         lat          lon  \
# 0     apartment     71.0   48550.59    19.52589   -99.151703
# 1         house    233.0  168636.73  19.2640539  -99.5727534
# 2         house    300.0   86932.69   19.268629   -99.671722
# 4     apartment     84.0   68508.67   19.511938   -96.871956
# 5         house    175.0  102763.00   20.689157  -103.366728
#
#                              state
# 0                 Distrito Federal
# 1                 Estado de México
# 2                 Estado de México
# 4  Veracruz de Ignacio de la Llave
# 5                          Jalisco

# %%
#concatenate the csv files,taking axis is 0
df=pd.concat([df1,df2,df3])
print(df.shape)
df.head()
# Out:
# (1736, 6)
#   property_type             state        lat         lon  area_m2  price_usd
# 0         house  Estado de México  19.560181  -99.233528    150.0   67965.56
# 1         house        Nuevo León  25.688436 -100.198807    186.0   63223.78
# 2     apartment          Guerrero  16.767704  -99.764383     82.0   84298.37
# 3     apartment          Guerrero  16.829782  -99.911012    150.0   94308.80
# 5         house           Yucatán  21.052583  -89.538639    205.0  105191.37

# %%
#saving the cleaned dataframe
df.to_csv("C:/Users/USER/Downloads/mexico data.clean.csv", index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %%
df=pd.read_csv(r"C:\Users\USER\Downloads\mexico data.clean.csv")
df.shape
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  1736 non-null   object
#  1   state          1736 non-null   object
#  2   lat            1736 non-null   float64
#  3   lon            1736 non-null   float64
#  4   area_m2        1736 non-null   float64
#  5   price_usd      1736 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 81.5+ KB
#   property_type             state        lat         lon  area_m2  price_usd
# 0         house  Estado de México  19.560181  -99.233528    150.0   67965.56
# 1         house        Nuevo León  25.688436 -100.198807    186.0   63223.78
# 2     apartment          Guerrero  16.767704  -99.764383     82.0   84298.37
# 3     apartment          Guerrero  16.829782  -99.911012    150.0   94308.80
# ...

# %%
# location data 
fig=px.scatter_mapbox(
    df, #from the cleaned dataframe
    lat="lat",
    lon="lon",
    center={"lat": 19.43, "lon": -99.13}, #map will be centered on mexico city
     width=600,  # Width of map
    height=600,  #height of 
    zoom=8, #how close the map zooms
)
# Add mapbox_style to figure layout
fig.update_layout(mapbox_style="open-street-map")
fig.show()

# %%
#state data
df["state"].head()
df["state"].nunique() #most unique data in our df
df["state"].unique()
df["state"].value_counts().head(10)  #prevalent state property
# Out:
# state
# Distrito Federal                   303
# Estado de México                   179
# Yucatán                            171
# Morelos                            160
# Querétaro                          128
# Veracruz de Ignacio de la Llave    117
# Puebla                              95
# Nuevo León                          83
# Jalisco                             60
# San Luis Potosí                     55
# Name: count, dtype: int64

# %%
#numerical stat
df[["area_m2","price_usd"]].head()
df[["area_m2","price_usd"]].describe()
# Out:
#            area_m2      price_usd
# count  1736.000000    1736.000000
# mean    170.261521  115331.980766
# std      80.594539   65426.173873
# min      60.000000   33157.890000
# 25%     101.750000   65789.470000
# 50%     156.000000   99262.130000
# 75%     220.000000  150846.665000
# max     385.000000  326733.660000

# %%
#Visualization by creating a histogram
plt.hist(df["area_m2"])
plt.xlabel("Area[sq meters]")
plt.ylabel("Frequency")
plt.title("Distribution of Home Sizes");

# %%
#Boxplot of the area to rep min and max, 25,50 and 75% respectively
plt.boxplot(df["area_m2"], vert=False)
plt.xlabel("Area[sq meter]")
plt.title("Distribution of Home Size");

# %%
#Histogram of price
plt.hist(df["price_usd"])
plt.xlabel("Price[usd]")
plt.ylabel("Frequency")
plt.title("Distribution of Home Prices");

# %%
#Boxplot of price_USD for min, max, and the quartile, mean and percentile and outliers
plt.boxplot(df["price_usd"], vert=False)
plt.xlabel("Price[usd]")
plt.title("Distribution of Home Prices");

# %%
#RESEARCH QUIZ: What influences house price in mexico?
#group by state
mean_price_by_state=df.groupby("state")["price_usd"].mean().sort_values(ascending=False)
mean_price_by_state
# Out:
# state
# Querétaro                          133955.913281
# Guanajuato                         133277.965833
# Nuevo León                         129221.985663
# Distrito Federal                   128347.267426
# Quintana Roo                       128065.416053
# Chihuahua                          127073.852000
# Jalisco                            123386.472167
# Estado de México                   122723.490503
# Campeche                           121734.633333
# Puebla                             121732.974000
# Guerrero                           119854.276122
# Sonora                             114547.883333
# Morelos                            112697.295625
# Aguascalientes                     110543.888000
# Baja California Sur                109069.339333
# Yucatán                            108580.388596
# Chiapas                            104342.313273
# Veracruz de Ignacio de la Llave     96928.125128
# Hidalgo                             94012.326471
# ...

# %%
#State Mean Bar Chart using pandas
mean_price_by_state.plot(
    kind="bar",
    xlabel="State",
    ylabel="Price[usd]",
    title="Mean House Price by State"
);

# %%
#price per square meter
df["price_per_m2"]=df["price_usd"]/df["area_m2"]
df.head()
# Out:
#   property_type             state        lat         lon  area_m2  price_usd  \
# 0         house  Estado de México  19.560181  -99.233528    150.0   67965.56
# 1         house        Nuevo León  25.688436 -100.198807    186.0   63223.78
# 2     apartment          Guerrero  16.767704  -99.764383     82.0   84298.37
# 3     apartment          Guerrero  16.829782  -99.911012    150.0   94308.80
# 4         house           Yucatán  21.052583  -89.538639    205.0  105191.37
#
#    price_per_m2
# 0    453.103733
# 1    339.912796
# 2   1028.028902
# 3    628.725333
# 4    513.128634

# %%
#use groupby
(
    df
    .groupby("state") 
    ["price_per_m2"].mean()
    .sort_values(ascending=False)
    .plot(
        kind="bar",
        xlabel="State",
        ylabel="Price[usd]",
        title="Mean House Price by State"
       )
);

# %%
#Price vs Area scatter plot to define the relationship between home size and price using matplotly 
plt.scatter(x=df["area_m2"], y=df["price_usd"])
plt.xlabel("Area[sq meters]")
plt.ylabel("Price [USD]")
plt.title("Price vs Area");

# %%
#representing the correlation numerically (using pearson correlation-coefficient)
p_correlation=df["area_m2"].corr(df["price_usd"])
print(p_correlation)
#hence there is a moderate relationship between house size and price in mexico states
# Out:
# 0.5855182453232063

# %%
# Let's look into one state, that is Morelos
df_Morelos=df[df["state"]=="Morelos"]
df_Morelos.head()
# Out:
#    property_type    state        lat        lon  area_m2  price_usd  \
# 6          house  Morelos  18.812605 -98.954826    281.0  151509.56
# 9          house  Morelos  18.804197 -98.932816    117.0   63223.78
# 18         house  Morelos  18.855343 -99.241142     73.0   36775.16
# 49         house  Morelos  18.804197 -98.932816    130.0   65858.10
# 55         house  Morelos  18.960244 -99.212962    305.0  227351.46
#
#     price_per_m2
# 6     539.179929
# 9     540.374188
# 18    503.769315
# 49    506.600769
# 55    745.414623

# %%
#Morelos, Price vs Area scatter plot
plt.scatter(x=df_Morelos["area_m2"],y=df_Morelos["price_usd"])
plt.xlabel("Area [sq meters]")
plt.ylabel("Price [USD]")
plt.title("Morelos:Price Vs Area");
#In this, it seems in Morelos, there is a stronger correlation

# %%
# Morelos, Correlation
p_correlation=df_Morelos["area_m2"].corr(df_Morelos["price_usd"])
print(p_correlation)
#Has a bigger correlation hence, there is a stronger relationship between house size and price in morelos
# Out:
# 0.8498077608713708

# %%
#mexico city, price vs Area
df_Mexico_city=df[df["state"]=="Distrito Federal"]
plt.scatter(x=df_Mexico_city["area_m2"],y=df_Mexico_city["price_usd"])
plt.xlabel("Area [sq meters]")
plt.ylabel("Price [USD]")
plt.title("Mexico city:Price Vs Area");

# %%
#Correlation
p_correlation=df_Mexico_city["area_m2"].corr(df_Mexico_city["price_usd"])
print(p_correlation)
# Out:
# 0.41070392130717864
